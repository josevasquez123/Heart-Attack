# %%
import pandas as pd

# %% [markdown]
# ### DATA EXPLORATION

# %%
df = pd.read_csv("../database/heart.csv")
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df.slp.unique()
# Out:
# array([0, 2, 1], dtype=int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.isna().sum()               #NO NULL VALUES
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
df[df.duplicated()]          #1 DUPLICATED VALUE
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 164   38    1   2     138   175    0        1       173     0      0.0    2
#
#      caa  thall  output
# 164    4      2       1

# %%
df.drop_duplicates(keep='first', inplace=True)
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [age, sex, cp, trtbps, chol, fbs, restecg, thalachh, exng, oldpeak, slp, caa, thall, output]
# Index: []

# %% [markdown]
# ### DATA VISUALIZATION

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x=df['output'])
plt.show()

# %%
sns.countplot(x=df['cp'])
plt.show()

# %%
sns.countplot(x=df['restecg'])
plt.show()

# %%
sns.countplot(x=df['fbs'])
plt.show()

# %%
sns.displot(data=df, x='age', label='Age', kde=True)
plt.show()

# %%
sns.displot(data=df, x='trtbps', label='Age', kde=True)
plt.show()

# %%
sns.displot(data=df, x='chol', label='Age', kde=True)
plt.show()

# %%
sns.displot(data=df, x='thalachh', label='Age', kde=True)
plt.show()

# %%
sns.displot(data=df, x='age', label='Age', kde=True, hue='output')
plt.show()

# %%
sns.displot(data=df, x='chol', label='Age', kde=True, hue='output')
plt.show()

# %%
sns.displot(data=df, x='thalachh', label='Age', kde=True, hue='output')
plt.show()

# %% [markdown]
# ### DATA PREPROCESSING

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from  sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
#THERE IS NO CATEGORICAL VALUES, SO WE ARE GONNA SPLIT DATA
x = df.drop(columns='output')
y = df['output']

# %%
x.shape, y.shape
# Out:
# ((302, 13), (302,))

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2)

# %% [markdown]
# #### LOGISTIC REGRESSION

# %%
model = LogisticRegression(max_iter=1000)
model.fit(x_train, y_train)
predict = model.predict(x_test)
print(f'Model Acc: {accuracy_score(y_test, predict)*100}')
# Out:
# Model Acc: 85.24590163934425

# %%
print(classification_report(y_test, predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.75      0.80        24
#            1       0.85      0.92      0.88        37
#
#     accuracy                           0.85        61
#    macro avg       0.85      0.83      0.84        61
# weighted avg       0.85      0.85      0.85        61

# %%
confusion_matrix(y_test, predict)
# Out:
# array([[18,  6],
#        [ 3, 34]], dtype=int64)

# %% [markdown]
# ### RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(n_estimators=250)
rf_model.fit(x_train,y_train)
rf_predict = rf_model.predict(x_test)
print(f'Model Acc: {accuracy_score(y_test, rf_predict)*100}')
# Out:
# Model Acc: 85.24590163934425

# %%
print(classification_report(y_test, predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.75      0.80        24
#            1       0.85      0.92      0.88        37
#
#     accuracy                           0.85        61
#    macro avg       0.85      0.83      0.84        61
# weighted avg       0.85      0.85      0.85        61

# %%
confusion_matrix(y_test, predict)
# Out:
# array([[18,  6],
#        [ 3, 34]], dtype=int64)

# %% [markdown]
# ### XGBOOST

# %%
from xgboost import XGBClassifier

# %%
bst = XGBClassifier(n_estimators=2, max_depth=3, learning_rate=1, objective='binary:logistic')
# fit model
bst.fit(x_train, y_train)
# make predictions
xg_predict = bst.predict(x_test)
print(f'Model Acc: {accuracy_score(y_test, xg_predict)*100}')
# Out:
# Model Acc: 81.9672131147541

# %%
print(classification_report(y_test, predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.75      0.80        24
#            1       0.85      0.92      0.88        37
#
#     accuracy                           0.85        61
#    macro avg       0.85      0.83      0.84        61
# weighted avg       0.85      0.85      0.85        61

# %%
confusion_matrix(y_test, predict)
# Out:
# array([[18,  6],
#        [ 3, 34]], dtype=int64)

# %% [markdown]
# ### SVM

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

# %%
svm_model = make_pipeline(StandardScaler(), SVC())
svm_model.fit(x_train, y_train)
svm_predict = svm_model.predict(x_test)
print(f'Model Acc: {accuracy_score(y_test, svm_predict)*100}')
# Out:
# Model Acc: 86.88524590163934

# %%
print(classification_report(y_test, svm_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.75      0.82        24
#            1       0.85      0.95      0.90        37
#
#     accuracy                           0.87        61
#    macro avg       0.88      0.85      0.86        61
# weighted avg       0.87      0.87      0.87        61

# %%
confusion_matrix(y_test, svm_predict)
# Out:
# array([[18,  6],
#        [ 2, 35]], dtype=int64)

# %% [markdown]
# ### SELECT FEATURES

# %%
f_i = list(zip(x.columns, rf_model.feature_importances_))
f_i.sort(key = lambda x : x[1])
plt.figure(figsize=(10,10))
plt.barh([x[0] for x in f_i],[x[1] for x in f_i])
plt.show()

# %%
column_feat = ['caa', 'thalachh', 'cp', 'thall', 'oldpeak', 'age', 'trtbps', 'chol', 'exng', 'slp']
x_featured = x[column_feat]

# %%
x_train, x_test, y_train, y_test = train_test_split(x_featured,y, test_size=0.2, random_state=42)

# %%
rf_model_feat = RandomForestClassifier(n_estimators=250)
rf_model_feat.fit(x_train,y_train)
rf_predict = rf_model_feat.predict(x_test)
print(f'Model Acc: {accuracy_score(y_test, rf_predict)*100}')
# Out:
# Model Acc: 86.88524590163934

# %%
print(classification_report(y_test, rf_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87        29
#            1       0.90      0.84      0.87        32
#
#     accuracy                           0.87        61
#    macro avg       0.87      0.87      0.87        61
# weighted avg       0.87      0.87      0.87        61

# %%
confusion_matrix(y_test, rf_predict)
# Out:
# array([[26,  3],
#        [ 5, 27]], dtype=int64)

# %% [markdown]
# - We got same results, but with less features
# - Recall of 0 (0.86) is higher than last models, this is a good improvement because we got less false negatives

# %% [markdown]
# ### TUNNING HYPER-PARAMETERS

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'bootstrap': [True],
    'max_depth': [80, 90, 100, 110],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'n_estimators': [100, 200, 300, 1000]
}
# Create a based model
rf = RandomForestClassifier()
# Instantiate the grid search model
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid)

grid_search.fit(x_train, y_train)

# the scores
print("The best params are :", grid_search.best_params_)
print("The best score is   :", grid_search.best_score_)

# predicting the values
y_pred = grid_search.predict(x_test)

# printing the test accuracy
print("The test accuracy score of SVM after hyper-parameter tuning is ", accuracy_score(y_test, y_pred))
# Out:
# The best params are : {'bootstrap': True, 'max_depth': 80, 'max_features': 2, 'min_samples_leaf': 5, 'min_samples_split': 12, 'n_estimators': 100}
# The best score is   : 0.8466836734693878
# The test accuracy score of SVM after hyper-parameter tuning is  0.8524590163934426

# %% [markdown]
# Even tunning hyper-parameters, we don't get better results. For that reason we use random forest model without tunning

# %% [markdown]
# ### EXPORT MODEL

# %%
import pickle

# %%
pickle.dump(rf_model_feat,open('../api/models/model.pkl','wb'))
pickle.dump(df, open('../app/models/df.pkl', 'wb'))
